# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:/Users/tonis/Downloads/demo_data.csv")
df
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 0       39         State-gov   77516   Bachelors             13
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 2       38           Private  215646     HS-grad              9
# 3       53           Private  234721        11th              7
# 4       28           Private  338409   Bachelors             13
# ...    ...               ...     ...         ...            ...
# 32556   27           Private  257302  Assoc-acdm             12
# 32557   40           Private  154374     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32560   52      Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation   relationship   race     sex  \
# 0           Never-married       Adm-clerical  Not-in-family  White    Male
# ...

# %%
# returns 5 first rows
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
df.head(3)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
#
#        marital-status         occupation   relationship   race   sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White  Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White  Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White  Male
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# 1             0             0              13  United-States  <=50K
# 2             0             0              40  United-States  <=50K

# %%
# returns 5 last rows
df.tail()
# Out:
#        age     workclass  fnlwgt   education  education-num  \
# 32556   27       Private  257302  Assoc-acdm             12
# 32557   40       Private  154374     HS-grad              9
# 32558   58       Private  151910     HS-grad              9
# 32559   22       Private  201490     HS-grad              9
# 32560   52  Self-emp-inc  287927     HS-grad              9
#
#            marital-status         occupation relationship   race     sex  \
# 32556  Married-civ-spouse       Tech-support         Wife  White  Female
# 32557  Married-civ-spouse  Machine-op-inspct      Husband  White    Male
# 32558             Widowed       Adm-clerical    Unmarried  White  Female
# 32559       Never-married       Adm-clerical    Own-child  White    Male
# 32560  Married-civ-spouse    Exec-managerial         Wife  White  Female
#
#        capital-gain  capital-loss  hours-per-week native-country salary
# 32556             0             0              38  United-States  <=50K
# ...

# %%
# returns random rows
df.sample(4)
# Out:
#        age  workclass  fnlwgt  education  education-num      marital-status  \
# 31166   47    Private  101299    HS-grad              9  Married-civ-spouse
# 5443    33    Private  214635    HS-grad              9  Married-civ-spouse
# 24006   29  State-gov  214284    Masters             14       Never-married
# 2264    24    Private  306779  Assoc-voc             11       Never-married
#
#             occupation relationship                race     sex  capital-gain  \
# 31166     Craft-repair      Husband               White    Male             0
# 5443   Exec-managerial      Husband               Black    Male             0
# 24006   Prof-specialty    Unmarried  Asian-Pac-Islander  Female             0
# 2264   Exec-managerial    Own-child               White    Male             0
#
#        capital-loss  hours-per-week native-country salary
# 31166             0              40  United-States  <=50K
# 5443              0              50  United-States  <=50K
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education-num   32561 non-null  int64
#  5   marital-status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital-gain    32561 non-null  int64
#  11  capital-loss    32561 non-null  int64
#  12  hours-per-week  32561 non-null  int64
#  13  native-country  32561 non-null  object
#  14  salary          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.describe()
# Out:
#                 age        fnlwgt  education-num  capital-gain  capital-loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours-per-week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
# 
df["capital-gain"].value_counts()
# Out:
# capital-gain
# 0        29849
# 15024      347
# 7688       284
# 7298       246
# 99999      159
#          ...
# 6097         1
# 1639         1
# 7978         1
# 2387         1
# 5060         1
# Name: count, Length: 119, dtype: int64

# %%
df["capital-gain"].value_counts(normalize=True)
# Out:
# capital-gain
# 0        0.916710
# 15024    0.010657
# 7688     0.008722
# 7298     0.007555
# 99999    0.004883
#            ...
# 6097     0.000031
# 1639     0.000031
# 7978     0.000031
# 2387     0.000031
# 5060     0.000031
# Name: proportion, Length: 119, dtype: float64

# %% [markdown]
# 1. How many people of each race are represented?

# %%
df.race.value_counts()
# Out:
# race
# White                 27816
# Black                  3124
# Asian-Pac-Islander     1039
# Amer-Indian-Eskimo      311
# Other                   271
# Name: count, dtype: int64

# %% [markdown]
# 2. What is the average age of men?

# %%
df[df["sex"] == "Male"] ["age"].mean().round(1)
# Out:
# np.float64(39.4)

# %% [markdown]
# 3. What is the precentage of people who have a Bacelor's degree?

# %%
round(df[df["education"] == "Bachelors"].shape[0] / len(df) * 100, 1)
# Out:
# 16.4

# %%
round(df.education.value_counts(normalize=True)["Bachelors"] * 100, 1)
# Out:
# np.float64(16.4)

# %% [markdown]
# 4. What precentage of people with advanced education make more than 50K?

# %%
# all education types
df.education.unique()
# Out:
# array(['Bachelors', 'HS-grad', '11th', 'Masters', '9th', 'Some-college',
#        'Assoc-acdm', 'Assoc-voc', '7th-8th', 'Doctorate', 'Prof-school',
#        '5th-6th', '10th', '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
df.salary.unique()
# Out:
# array(['<=50K', '>50K'], dtype=object)

# %%
# number of people with that kind of education
df["education-num"].unique()
# Out:
# array([13,  9,  7, 14,  5, 10, 12, 11,  4, 16, 15,  3,  6,  2,  1,  8])

# %%
# number of people with that kind of education in a dictionary
edu_dict = dict(zip(df.education.unique(), df["education-num"].unique()))
edu_dict
# Out:
# {'Bachelors': np.int64(13),
#  'HS-grad': np.int64(9),
#  '11th': np.int64(7),
#  'Masters': np.int64(14),
#  '9th': np.int64(5),
#  'Some-college': np.int64(10),
#  'Assoc-acdm': np.int64(12),
#  'Assoc-voc': np.int64(11),
#  '7th-8th': np.int64(4),
#  'Doctorate': np.int64(16),
#  'Prof-school': np.int64(15),
#  '5th-6th': np.int64(3),
#  '10th': np.int64(6),
#  '1st-4th': np.int64(2),
#  'Preschool': np.int64(1),
#  '12th': np.int64(8)}

# %%
df.head(7)
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
# 5   37           Private  284582    Masters             14
# 6   49           Private  160187        9th              5
#
#           marital-status         occupation   relationship   race     sex  \
# 0          Never-married       Adm-clerical  Not-in-family  White    Male
# 1     Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2               Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3     Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4     Married-civ-spouse     Prof-specialty           Wife  Black  Female
# ...

# %%
h_edu = df[(df["education-num"] >= 13) & (df["education-num"] != 15)]
h_edu ["education"].unique()
# Out:
# array(['Bachelors', 'Masters', 'Doctorate'], dtype=object)

# %%
round(h_edu[h_edu.salary == ">50K"].shape[0] / h_edu.shape[0] * 100, 1)
# Out:
# 46.5

# %% [markdown]
# 5. What precentage of people without advanced education make more than 50K?

# %%
l_edu = df[(df["education-num"] < 13) | (df["education-num"] == 15)]
l_edu ["education"].unique()
# Out:
# array(['HS-grad', '11th', '9th', 'Some-college', 'Assoc-acdm',
#        'Assoc-voc', '7th-8th', 'Prof-school', '5th-6th', '10th',
#        '1st-4th', 'Preschool', '12th'], dtype=object)

# %%
round(l_edu[l_edu.salary == ">50K"].shape[0] / l_edu.shape[0] * 100, 1)
# Out:
# 17.4

# %% [markdown]
# 6. What is the minimum number of hours a person works per week?

# %%
df["hours-per-week"].min()
# Out:
# np.int64(1)

# %% [markdown]
# 7. What precentage of the people who work the minimum number of hours per week have a salary of more that 50K?

# %%
# 
min_workers = df[df["hours-per-week"] == df["hours-per-week"].min()]
min_workers.head()
# Out:
#       age     workclass  fnlwgt  education  education-num      marital-status  \
# 189    58     State-gov  109567  Doctorate             16  Married-civ-spouse
# 1036   66  Self-emp-inc  150726        9th              5  Married-civ-spouse
# 1262   69             ?  195779  Assoc-voc             11             Widowed
# 5590   78             ?  363134    HS-grad              9             Widowed
# 5632   45             ?  189564    Masters             14  Married-civ-spouse
#
#            occupation   relationship   race     sex  capital-gain  \
# 189    Prof-specialty        Husband  White    Male             0
# 1036  Exec-managerial        Husband  White    Male          1409
# 1262                ?  Not-in-family  White  Female             0
# 5590                ?  Not-in-family  White  Female             0
# 5632                ?           Wife  White  Female             0
#
#       capital-loss  hours-per-week native-country salary
# ...

# %%
# how many number of people work less than 1h per day and nr of columns
min_workers.shape
# Out:
# (20, 15)

# %%
# precentage of people
round(min_workers[min_workers["salary"] == ">50K"].shape[0] / min_workers.shape[0] * 100, 1)
# Out:
# 10.0

# %% [markdown]
# 8. People from whitch native country have the highest precentage of those who earn >50K and what is that precentage?

# %%
salary_table = df[df.salary == ">50K"]["native-country"].value_counts() / df["native-country"].value_counts()

# %%
salary_table.sort_values(ascending=False).head(1).round(3) * 100
# Out:
# native-country
# Iran    41.9
# Name: count, dtype: float64

# %% [markdown]
# 9. What is the most popular occupation for those whoe are originated from India and earn >50K?

# %% [markdown]
# 10. How many people who work in private sector have the age outside 3 standard deviation from the average age?

# %%
# Mean age in Private sector
age_mean = df[df.workclass == "Private"]["age"].mean()
age_mean
# Out:
# np.float64(36.797585477617204)

# %%
# Standard deviation of
age_std = df[df.workclass == "Private"]["age"].std()
age_std
# Out:
# np.float64(12.827721323558896)

# %%
# Outliers
df[(df.workclass == "Private") & ((df.age > age_mean + 3 * age_std) | (df.age < age_mean - 3 * age_std))].shape[0]
# Out:
# 95

# %% [markdown]
# 11. Some methods

# %% [markdown]
# Between

# %%
# Filterd column between two values (Returns boolean)
df.age.between(30, 40)
# Out:
# 0         True
# 1        False
# 2         True
# 3        False
# 4        False
#          ...
# 32556    False
# 32557     True
# 32558    False
# 32559    False
# 32560    False
# Name: age, Length: 32561, dtype: bool

# %%
# Returns max
df[df.age.between(30, 40, "neither")].max()
# Out:
# age                             39
# workclass                State-gov
# fnlwgt                     1455435
# education             Some-college
# education-num                   16
# marital-status             Widowed
# occupation        Transport-moving
# relationship                  Wife
# race                         White
# sex                           Male
# capital-gain                 99999
# capital-loss                  3770
# hours-per-week                  99
# native-country          Yugoslavia
# salary                        >50K
# dtype: object

# %% [markdown]
# Select dtypes

# %% [markdown]
# #
# df.select_dtypes(exclude="object").head()

# %% [markdown]
# nlargest & nsmallest

# %%
# number of rows with the highest capital-loss
df.nlargest(5, "capital-loss")
# Out:
#        age workclass  fnlwgt     education  education-num marital-status  \
# 8963    90         ?   77053       HS-grad              9        Widowed
# 14756   82   Private  132870       HS-grad              9        Widowed
# 30781   66         ?  186061  Some-college             10        Widowed
# 20416   54   Private  140359       7th-8th              4       Divorced
# 23802   41   Private  264663  Some-college             10      Separated
#
#               occupation   relationship   race     sex  capital-gain  \
# 8963                   ?  Not-in-family  White  Female             0
# 14756    Exec-managerial  Not-in-family  White  Female             0
# 30781                  ?      Unmarried  Black  Female             0
# 20416  Machine-op-inspct      Unmarried  White  Female             0
# 23802     Prof-specialty      Own-child  White  Female             0
#
#        capital-loss  hours-per-week native-country salary
# ...

# %% [markdown]
# Replace

# %%
df.replace(0, 1000).head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174          1000              40  United-States  <=50K
# ...

# %%
df.replace(["Male", "Female", "United-States"], ["M", "F", "USA"]).head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White   M
# 1  Married-civ-spouse    Exec-managerial        Husband  White   M
# 2            Divorced  Handlers-cleaners  Not-in-family  White   M
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black   M
# 4  Married-civ-spouse     Prof-specialty           Wife  Black   F
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40            USA  <=50K
# 1             0             0              13            USA  <=50K
# ...

# %%
# replace with Unknown
df.replace(["Male", "Female"], "Unknown").head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race      sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White  Unknown
# 1  Married-civ-spouse    Exec-managerial        Husband  White  Unknown
# 2            Divorced  Handlers-cleaners  Not-in-family  White  Unknown
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black  Unknown
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Unknown
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# replace particular column
df.replace({"capital-gain": {2174: 0, 0:1000}, "capital-loss": {0: 5000}}).head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0             0          5000              40  United-States  <=50K
# ...

# %% [markdown]
# Lambda

# %%
df[["age", "race", "sex"]].apply(lambda x: "Is a {} {} {} years old".format(x["race"], x["sex"], x["age"]), axis=1)
# Out:
# 0          Is a White Male 39 years old
# 1          Is a White Male 50 years old
# 2          Is a White Male 38 years old
# 3          Is a Black Male 53 years old
# 4        Is a Black Female 28 years old
#                       ...
# 32556    Is a White Female 27 years old
# 32557      Is a White Male 40 years old
# 32558    Is a White Female 58 years old
# 32559      Is a White Male 22 years old
# 32560    Is a White Female 52 years old
# Length: 32561, dtype: object

# %%
df.select_dtypes("number").apply(lambda x: f'{x.mean():.2f} +/- {x.std():.2f}')
# Out:
# age                       38.58 +/- 13.64
# fnlwgt            189778.37 +/- 105549.98
# education-num              10.08 +/- 2.57
# capital-gain          1077.65 +/- 7385.29
# capital-loss             87.30 +/- 402.96
# hours-per-week            40.44 +/- 12.35
# dtype: object

# %%
df.applymap(id).head()
# Out:
# C:\Users\tonis\AppData\Local\Temp\ipykernel_11176\1548429633.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df.applymap(id).head()
#              age      workclass         fnlwgt      education  education-num  \
# 0  2774354757040  2774537013680  2774535398736  2774537014576  2774354756208
# 1  2774354757392  2774537114672  2772890697456  2774537014576  2774354756208
# 2  2774354757008  2774537012848  2772890697296  2774537014192  2774354756080
# 3  2774354757488  2774537012848  2772890697520  2774537013936  2774354756016
# 4  2774354756688  2774537012848  2772890697168  2774537014576  2774354756208
#
#    marital-status     occupation   relationship           race            sex  \
# 0   2774537015152  2774537013168  2774537016496  2774537017008  2774537017264
# 1   2774537114752  2774537015472  2774537016240  2774537017008  2774537017264
# 2   2774537015664  2774537114992  2774537016496  2774537017008  2774537017264
# ...

# %% [markdown]
# Sort values

# %%
# sort by age
df.sort_values("age")
# Out:
#        age workclass  fnlwgt  education  education-num      marital-status  \
# 18470   17         ?   86786       10th              6       Never-married
# 18469   17   Private  104232       10th              6       Never-married
# 32282   17   Private  311907       11th              7       Never-married
# 476     17   Private  211870        9th              5       Never-married
# 25162   17   Private  342752       11th              7       Never-married
# ...    ...       ...     ...        ...            ...                 ...
# 4109    90         ?  256514  Bachelors             13             Widowed
# 11731   90         ?   39824    HS-grad              9             Widowed
# 11512   90   Private   87285    HS-grad              9       Never-married
# 4070    90   Private  313986       11th              7       Never-married
# 1935    90   Private  221832  Bachelors             13  Married-civ-spouse
#
# ...

# %%
df.sort_values(["age", "hours-per-week"], ascending=[True, False])
# Out:
#        age         workclass  fnlwgt     education  education-num  \
# 335     17           Private  270942       5th-6th              3
# 4667    17           Private   48610          11th              7
# 9971    17           Private  168807       7th-8th              4
# 30898   17         Local-gov  192387           9th              5
# 431     17                 ?  202521          11th              7
# ...    ...               ...     ...           ...            ...
# 24043   90  Self-emp-not-inc   82628       HS-grad              9
# 4109    90                 ?  256514     Bachelors             13
# 12451   90                 ?  225063  Some-college             10
# 18413   90           Private  313749     Bachelors             13
# 11731   90                 ?   39824       HS-grad              9
#
#       marital-status       occupation    relationship                race  \
# 335    Never-married    Other-service  Other-relative               White
# ...

# %%
# sort rows by index
df.sort_index(ascending=False)
# Out:
#        age         workclass  fnlwgt   education  education-num  \
# 32560   52      Self-emp-inc  287927     HS-grad              9
# 32559   22           Private  201490     HS-grad              9
# 32558   58           Private  151910     HS-grad              9
# 32557   40           Private  154374     HS-grad              9
# 32556   27           Private  257302  Assoc-acdm             12
# ...    ...               ...     ...         ...            ...
# 4       28           Private  338409   Bachelors             13
# 3       53           Private  234721        11th              7
# 2       38           Private  215646     HS-grad              9
# 1       50  Self-emp-not-inc   83311   Bachelors             13
# 0       39         State-gov   77516   Bachelors             13
#
#            marital-status         occupation   relationship   race     sex  \
# 32560  Married-civ-spouse    Exec-managerial           Wife  White  Female
# ...

# %% [markdown]
# ## Groupby

# %%
groups = df.groupby("education")

# %%
groups

# %%
# the same as df[df["education"] == "Masters"}]
groups.get_group("Masters")
# Out:
#        age         workclass  fnlwgt education  education-num  \
# 5       37           Private  284582   Masters             14
# 8       31           Private   45781   Masters             14
# 19      43  Self-emp-not-inc  292175   Masters             14
# 47      44           Private  128354   Masters             14
# 87      33           Private  202051   Masters             14
# ...    ...               ...     ...       ...            ...
# 32504   50           Private  208630   Masters             14
# 32513   46           Private   42972   Masters             14
# 32544   31           Private  199655   Masters             14
# 32553   32           Private  116138   Masters             14
# 32554   53           Private  321865   Masters             14
#
#            marital-status       occupation   relationship                race  \
# 5      Married-civ-spouse  Exec-managerial           Wife               White
# ...

# %% [markdown]
# Value_counts

# %%
groups.value_counts().to_frame()
# Out:
#                                                                                                                                                                                                  count
# education    age workclass        fnlwgt education-num marital-status     occupation      relationship race               sex    capital-gain capital-loss hours-per-week native-country salary
# 10th         17  ?                34019  6             Never-married      ?               Own-child    White              Male   0            0            20             United-States  <=50K       1
#                                   64785  6             Never-married      ?               Own-child    White              Male   0            0            30             United-States  <=50K       1
#                                   67808  6             Never-married      ?               Own-child    White              Male   0            0            40             United-States  <=50K       1
# ...

# %% [markdown]
# Mean age for every group

# %%
groups.age.mean().sort_values().info
# Out:
# <bound method Series.info of education
# 12th            32.000000
# 11th            32.355745
# Some-college    35.756275
# Assoc-acdm      37.381443
# 10th            37.429796
# Assoc-voc       38.553546
# Bachelors       38.904949
# HS-grad         38.974479
# 9th             41.060311
# Preschool       42.764706
# 5th-6th         42.885886
# Masters         44.049913
# Prof-school     44.746528
# 1st-4th         46.142857
# Doctorate       47.702179
# 7th-8th         48.445820
# Name: age, dtype: float64>

# %% [markdown]
# Aggregation

# %%
 groups.agg({"age":"mean"})
# Out:
#                     age
# education
# 10th          37.429796
# 11th          32.355745
# 12th          32.000000
# 1st-4th       46.142857
# 5th-6th       42.885886
# 7th-8th       48.445820
# 9th           41.060311
# Assoc-acdm    37.381443
# Assoc-voc     38.553546
# Bachelors     38.904949
# Doctorate     47.702179
# HS-grad       38.974479
# Masters       44.049913
# Preschool     42.764706
# Prof-school   44.746528
# Some-college  35.756275

# %%
age_df = groups.agg({"age": ["count", "mean", "std"]})
age_df
# Out:
#                 age
#               count       mean        std
# education
# 10th            933  37.429796  16.720713
# 11th           1175  32.355745  15.545485
# 12th            433  32.000000  14.334625
# 1st-4th         168  46.142857  15.615625
# 5th-6th         333  42.885886  15.557285
# 7th-8th         646  48.445820  16.092350
# 9th             514  41.060311  15.946862
# Assoc-acdm     1067  37.381443  11.095177
# Assoc-voc      1382  38.553546  11.631300
# Bachelors      5355  38.904949  11.912210
# Doctorate       413  47.702179  11.784716
# HS-grad       10501  38.974479  13.541524
# Masters        1723  44.049913  11.068935
# Preschool        51  42.764706  15.126914
# Prof-school     576  44.746528  11.962477
# Some-college   7291  35.756275  13.474051

# %%
age_df["age"]["count"]
# Out:
# education
# 10th              933
# 11th             1175
# 12th              433
# 1st-4th           168
# 5th-6th           333
# 7th-8th           646
# 9th               514
# Assoc-acdm       1067
# Assoc-voc        1382
# Bachelors        5355
# Doctorate         413
# HS-grad         10501
# Masters          1723
# Preschool          51
# Prof-school       576
# Some-college     7291
# Name: count, dtype: int64

# %%
# shows structure of multiIndex columns
age_df.columns
# Out:
# MultiIndex([('age', 'count'),
#             ('age',  'mean'),
#             ('age',   'std')],
#            )

# %%
# joins 
age_df.coumns = age_df.columns.map(' _ '.join)

# %%
age_df
# Out:
#                 age
#               count       mean        std
# education
# 10th            933  37.429796  16.720713
# 11th           1175  32.355745  15.545485
# 12th            433  32.000000  14.334625
# 1st-4th         168  46.142857  15.615625
# 5th-6th         333  42.885886  15.557285
# 7th-8th         646  48.445820  16.092350
# 9th             514  41.060311  15.946862
# Assoc-acdm     1067  37.381443  11.095177
# Assoc-voc      1382  38.553546  11.631300
# Bachelors      5355  38.904949  11.912210
# Doctorate       413  47.702179  11.784716
# HS-grad       10501  38.974479  13.541524
# Masters        1723  44.049913  11.068935
# Preschool        51  42.764706  15.126914
# Prof-school     576  44.746528  11.962477
# Some-college   7291  35.756275  13.474051

# %%
groups.agg({"age": ["min", "max"], "hours-per-week": "median"})
# Out:
#              age     hours-per-week
#              min max         median
# education
# 10th          17  90           40.0
# 11th          17  90           40.0
# 12th          17  79           40.0
# 1st-4th       19  90           40.0
# 5th-6th       17  84           40.0
# 7th-8th       17  90           40.0
# 9th           17  90           40.0
# Assoc-acdm    19  90           40.0
# Assoc-voc     19  84           40.0
# Bachelors     19  90           40.0
# Doctorate     24  80           45.0
# HS-grad       17  90           40.0
# Masters       18  90           40.0
# Preschool     19  75           40.0
# Prof-school   25  90           48.0
# Some-college  17  90           40.0

# %% [markdown]
# Standard error

# %%
# use lambda fuction to find a quadratic mean (root square mean)
groups.agg({
    "age": ["min", "max"],
    "hours-per-week": "median",
    "capital-gain": [("standard-error", lambda x: np.std(x) / np.sqrt(len(x)))]
})
# Out:
#              age     hours-per-week   capital-gain
#              min max         median standard-error
# education
# 10th          17  90           40.0     159.241562
# 11th          17  90           40.0      36.065894
# 12th          17  79           40.0      79.920572
# 1st-4th       19  90           40.0      60.711050
# 5th-6th       17  84           40.0      51.458047
# 7th-8th       17  90           40.0      40.480750
# 9th           17  90           40.0     196.385040
# Assoc-acdm    19  90           40.0     117.480831
# Assoc-voc     19  84           40.0      97.815558
# Bachelors     19  90           40.0     126.378981
# Doctorate     24  80           45.0     847.273856
# HS-grad       17  90           40.0      48.681283
# Masters       18  90           40.0     262.814580
# Preschool     19  75           40.0     805.038830
# Prof-school   25  90           48.0    1125.999905
# Some-college  17  90           40.0      56.028977

# %% [markdown]
# We can group by 2 or more columns

# %%
new_groups = df.groupby(["education", "workclass", "occupation"])

# %%
new_groups.age.mean().to_frame()
# Out:
#                                                  age
# education    workclass   occupation
# 10th         ?           ?                 33.980000
#              Federal-gov Craft-repair      59.750000
#                          Other-service     43.500000
#              Local-gov   Adm-clerical      54.500000
#                          Craft-repair      41.166667
# ...                                              ...
# Some-college State-gov   Sales             46.500000
#                          Tech-support      28.888889
#                          Transport-moving  43.000000
#              Without-pay Adm-clerical      62.000000
#                          Farming-fishing   48.500000
#
# [756 rows x 1 columns]

# %% [markdown]
# 756 rows x 1 colums

# %%
# reset index
new_groups.age.mean().to_frame().reset_index()
# Out:
#         education    workclass        occupation        age
# 0            10th            ?                 ?  33.980000
# 1            10th  Federal-gov      Craft-repair  59.750000
# 2            10th  Federal-gov     Other-service  43.500000
# 3            10th    Local-gov      Adm-clerical  54.500000
# 4            10th    Local-gov      Craft-repair  41.166667
# ..            ...          ...               ...        ...
# 751  Some-college    State-gov             Sales  46.500000
# 752  Some-college    State-gov      Tech-support  28.888889
# 753  Some-college    State-gov  Transport-moving  43.000000
# 754  Some-college  Without-pay      Adm-clerical  62.000000
# 755  Some-college  Without-pay   Farming-fishing  48.500000
#
# [756 rows x 4 columns]

# %% [markdown]
# ## Pivot table

# %%
df.head()
# Out:
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# 2   38           Private  215646    HS-grad              9
# 3   53           Private  234721       11th              7
# 4   28           Private  338409  Bachelors             13
#
#        marital-status         occupation   relationship   race     sex  \
# 0       Never-married       Adm-clerical  Not-in-family  White    Male
# 1  Married-civ-spouse    Exec-managerial        Husband  White    Male
# 2            Divorced  Handlers-cleaners  Not-in-family  White    Male
# 3  Married-civ-spouse  Handlers-cleaners        Husband  Black    Male
# 4  Married-civ-spouse     Prof-specialty           Wife  Black  Female
#
#    capital-gain  capital-loss  hours-per-week native-country salary
# 0          2174             0              40  United-States  <=50K
# ...

# %%
# drop useless columns
df.drop(["fnlwgt", "education-num"], axis=1, inplace=True)

# %%
pd.pivot_table(data=df, index=["sex", "salary"], values=df.select_dtypes("number"))
# Out:
#                      age  capital-gain  capital-loss  hours-per-week
# sex    salary
# Female <=50K   36.210801    121.986134     47.364470       35.916701
#        >50K    42.125530   4200.389313    173.648855       40.426633
# Male   <=50K   37.147012    165.723823     56.806782       40.693879
#        >50K    44.625788   3971.765836    198.780396       46.366106

# %%
df.pivot_table(index="education", aggfunc={"age": "median", "capital-gain": "sum"})
# Out:
#                age  capital-gain
# education
# 10th          34.0        377468
# 11th          28.0        252740
# 12th          28.0        123010
# 1st-4th       46.0         21147
# 5th-6th       42.0         58615
# 7th-8th       50.0        151125
# 9th           39.0        175834
# Assoc-acdm    36.0        683306
# Assoc-voc     37.0        988201
# Bachelors     37.0       9404984
# Doctorate     47.0       1970070
# HS-grad       37.0       6056978
# Masters       43.0       4415297
# Preschool     41.0         45818
# Prof-school   43.0       5998704
# Some-college  34.0       4366027

# %%
pd.pivot_table(df, index="occupation", columns="education", values="age", aggfunc="median")
# Out:
# education          10th  11th  12th  1st-4th  5th-6th  7th-8th   9th  \
# occupation
# ?                  22.0  21.0  22.0     65.0     56.0     62.0  49.0
# Adm-clerical       43.5  23.0  26.5      NaN     39.0     55.0  45.5
# Armed-Forces        NaN   NaN  34.0      NaN      NaN      NaN   NaN
# Craft-repair       38.5  32.0  35.5     49.0     42.0     47.0  36.0
# Exec-managerial    48.5  39.5  47.0     54.5     56.0     52.0  53.0
# Farming-fishing    36.5  35.0  27.5     37.0     37.0     53.5  42.0
# Handlers-cleaners  28.0  23.0  21.5     34.5     32.0     34.5  36.0
# Machine-op-inspct  38.0  37.0  32.0     42.0     44.0     49.0  37.0
# Other-service      27.5  24.0  20.0     45.5     39.0     50.5  41.0
# Priv-house-serv    21.5  20.0  24.5     54.0     42.0     56.0  51.5
# Prof-specialty     29.0  18.0  19.5     46.5     73.0     49.0  28.0
# Protective-serv    39.5  36.0  32.5     44.0     73.0     64.0  45.0
# ...

# %%
pd.pivot_table(df, index="education", columns="workclass", values="age", aggfunc="median")
# Out:
# workclass        ?  Federal-gov  Local-gov  Never-worked  Private  \
# education
# 10th          24.0         58.5       49.0          17.5     33.0
# 11th          21.5         46.0       35.0          18.0     27.0
# 12th          22.0         34.0       44.0           NaN     26.0
# 1st-4th       65.0          NaN       55.5           NaN     41.5
# 5th-6th       56.0         35.0       53.0           NaN     41.0
# 7th-8th       62.0         56.0       52.5          23.0     47.0
# 9th           49.0         35.0       51.0           NaN     37.0
# Assoc-acdm    32.0         40.0       39.0           NaN     35.0
# Assoc-voc     41.0         43.0       39.0           NaN     36.0
# Bachelors     46.0         42.0       38.0           NaN     36.0
# Doctorate     67.0         49.0       51.0           NaN     45.0
# HS-grad       46.0         43.0       42.0          30.0     35.0
# Masters       55.0         43.0       45.0           NaN     42.0
# ...
