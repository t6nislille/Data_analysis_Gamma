# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/tonis/Downloads/baltics_dividends.csv")
df
# Out:
#    market ticker   price  years_from  years_to  years_count  total_years  \
# 0     VLN  AMG1L   1.250        2015      2022            8            6
# 1     VLN  APG1L   1.890        2015      2022            8            6
# 2     TLN  ARC1T   1.792        2015      2023            9            9
# 3     RIG  BAL1R  10.000        2021      2022            2            2
# 4     TLN  CPA1T   2.264        2022      2022            1            1
# 5     VLN  CTS1L   2.000        2015      2015            1            1
# 6     RIG  DGR1R   1.452        2021      2022            2            2
# 7     TLN  EEG1T   1.495        2015      2022            8            6
# 8     TLN  EFT1T  19.850        2018      2022            5            5
# 9     TLN  EGR1T   4.240        2022      2022            1            1
# 10    VLN  EWA1L  16.600        2017      2022            6            4
# 11    VLN  GRG1L   0.754        2015      2022            8            7
# ...

# %% [markdown]
# ### 1. Set the column ticker as a new index of the DataFrame.
